# %%
# Se importa la libreria a usar
import pandas as pd

# %%
# Se crea un dataframe para cargar el archivo .xlsx
libro = pd.read_excel('homicidios.xlsx', sheet_name=None)

# %%
# Para conocer cuantas hojas tiene el archivo procedemos a imprimirlas

nombre_de_hojas = list(libro.keys())
print(f'Los nombre de la hojas en el archivo de excel son: {nombre_de_hojas}')
# Out:
# Los nombre de la hojas en el archivo de excel son: ['HECHOS', 'DICCIONARIO_HECHOS', 'VICTIMAS', 'DICCIONARIO_VICTIMAS', 'clas']

# %%
# Creamos el Dataframe hechos con la hoja Hechos del archivo .xlsx
hechos = libro['HECHOS']

# %%
hechos.head()
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                         AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                                  NaN
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
#
#                                Dirección Normalizada COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 2                                ENTRE RIOS AV. 2034      1
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.      8
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.      1
#
#                                  XY (CABA)         pos x         pos y  \
# 0    Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1    Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2   Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3    Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4  Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
#
#     PARTICIPANTES VICTIMA    ACUSADO
# 0       MOTO-AUTO    MOTO       AUTO
# 1  AUTO-PASAJEROS    AUTO  PASAJEROS
# 2       MOTO-AUTO    MOTO       AUTO
# 3         MOTO-SD    MOTO         SD
# 4  MOTO-PASAJEROS    MOTO  PASAJEROS
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Una vez revisado el contenido del libro Hechos se procede a ver si existen duplicados en la columna ID

# %%
hechos['ID'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Se crea el Dataframe victimas para conocer su contenido

# %%
victimas = libro['VICTIMAS']

# %%
victimas.head()
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO EDAD  \
# 0  2016-0001 2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO   19
# 1  2016-0002 2016-01-02  2016   1   2  CONDUCTOR    AUTO  MASCULINO   70
# 2  2016-0003 2016-01-03  2016   1   3  CONDUCTOR    MOTO  MASCULINO   30
# 3  2016-0004 2016-01-10  2016   1  10  CONDUCTOR    MOTO  MASCULINO   18
# 4  2016-0005 2016-01-21  2016   1  21  CONDUCTOR    MOTO  MASCULINO   29
#
#    FECHA_FALLECIMIENTO
# 0  2016-01-01 00:00:00
# 1  2016-01-02 00:00:00
# 2  2016-01-03 00:00:00
# 3                   SD
# 4  2016-02-01 00:00:00

# %%
# se verifican que columnas y de que tipo son sus datos 
victimas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_hecho             717 non-null    object
#  1   FECHA                717 non-null    datetime64[ns]
#  2   AAAA                 717 non-null    int64
#  3   MM                   717 non-null    int64
#  4   DD                   717 non-null    int64
#  5   ROL                  717 non-null    object
#  6   VICTIMA              717 non-null    object
#  7   SEXO                 717 non-null    object
#  8   EDAD                 717 non-null    object
#  9   FECHA_FALLECIMIENTO  717 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 56.1+ KB

# %%
duplicados = victimas[victimas['ID_hecho'].duplicated()]
duplicados

# %% [markdown]
# ##### Se verifca la existencia de estas filas duplicadas y es logica ya que un hecho puede tener varias victimas

# %% [markdown]
# ## Se procede a definir a victimas con las columnas que ncesitamos para unir al dataframe de Hechos

# %%
victimas = victimas[['ID_hecho','ROL','SEXO','EDAD','FECHA_FALLECIMIENTO']]

# %%
victimas.rename(columns={'ID_hecho': 'ID'}, inplace=True)
# Out:
# C:\Users\felix\AppData\Local\Temp\ipykernel_28412\654063845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   victimas.rename(columns={'ID_hecho': 'ID'}, inplace=True)

# %%
merge_datos = pd.merge(victimas,hechos, on='ID',how='left')

# %%
merge_datos
# Out:
#             ID                   ROL       SEXO EDAD  FECHA_FALLECIMIENTO  \
# 0    2016-0001             CONDUCTOR  MASCULINO   19  2016-01-01 00:00:00
# 1    2016-0002             CONDUCTOR  MASCULINO   70  2016-01-02 00:00:00
# 2    2016-0003             CONDUCTOR  MASCULINO   30  2016-01-03 00:00:00
# 3    2016-0004             CONDUCTOR  MASCULINO   18                   SD
# 4    2016-0005             CONDUCTOR  MASCULINO   29  2016-02-01 00:00:00
# ..         ...                   ...        ...  ...                  ...
# 712  2021-0092                PEATON   FEMENINO   50  2021-12-12 00:00:00
# 713  2021-0093  PASAJERO_ACOMPAÑANTE   FEMENINO   18  2021-12-18 00:00:00
# 714  2021-0094  PASAJERO_ACOMPAÑANTE   FEMENINO   43  2021-12-20 00:00:00
# 715  2021-0095             CONDUCTOR  MASCULINO   27  2022-01-02 00:00:00
# 716  2021-0096             CONDUCTOR  MASCULINO   60  2021-12-20 00:00:00
#
#      N_VICTIMAS      FECHA  AAAA  MM  DD  ...  Altura  \
# 0             1 2016-01-01  2016   1   1  ...     NaN
# 1             1 2016-01-02  2016   1   2  ...     NaN
# 2             1 2016-01-03  2016   1   3  ...  2034.0
# 3             1 2016-01-10  2016   1  10  ...     NaN
# 4             1 2016-01-21  2016   1  21  ...     NaN
# ..          ...        ...   ...  ..  ..  ...     ...
# 712           1 2021-12-12  2021  12  12  ...     NaN
# 713           1 2021-12-13  2021  12  13  ...     NaN
# 714           1 2021-12-20  2021  12  20  ...     NaN
# 715           1 2021-12-30  2021  12  30  ...     NaN
# 716           1 2021-12-15  2021  12  15  ...  4071.0
#
#                                    Cruce  \
# 0    FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                    DE LOS CORRALES AV.
# 2                                    NaN
# 3               VILLEGAS, CONRADO, GRAL.
# 4                SAENZ PE?A, LUIS, PRES.
# ..                                   ...
# 712                       PUEYRREDON AV.
# 713                                  MOM
# 714                          LACARRA AV.
# 715                              TERRADA
# 716                                  NaN
#
#                                  Dirección Normalizada COMUNA  \
# 0    PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
# 1                 PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 2                                  ENTRE RIOS AV. 2034      1
# 3            LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.      8
# 4              SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.      1
# ..                                                 ...    ...
# 712                     RIVADAVIA AV. y PUEYRREDON AV.      3
# 713                                  RIESTRA AV. y MOM      7
# 714         DELLEPIANE, LUIS, TTE. GRAL. y LACARRA AV.      9
# 715                                GAONA AV. y TERRADA     11
# 716                                PERON, EVA AV. 4071      9
#
#                                    XY (CABA)         pos x         pos y  \
# 0      Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1      Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2     Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3      Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4    Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
# ..                                       ...           ...           ...
# 712  Point (105258.35368554 102122.93231400)  -58.40596860  -34.61011987
# 713   Point (102728.60090138 98186.24929177)  -58.43353773  -34.64561636
# 714    Point (99624.29795829 97569.69801131)  -58.46739825  -34.65117757
# 715   Point (99116.45492358 101045.23284826)  -58.47293407  -34.61984745
# 716    Point (99324.54463985 97676.26932409)  -58.47066794  -34.65021673
#
#       PARTICIPANTES  VICTIMA    ACUSADO
# 0         MOTO-AUTO     MOTO       AUTO
# 1    AUTO-PASAJEROS     AUTO  PASAJEROS
# 2         MOTO-AUTO     MOTO       AUTO
# 3           MOTO-SD     MOTO         SD
# 4    MOTO-PASAJEROS     MOTO  PASAJEROS
# ..              ...      ...        ...
# 712     PEATON-AUTO   PEATON       AUTO
# 713       MOTO-AUTO     MOTO       AUTO
# 714       MOTO-AUTO     MOTO       AUTO
# 715     MOTO-CARGAS     MOTO     CARGAS
# 716     AUTO-CARGAS     AUTO     CARGAS
#
# [717 rows x 25 columns]

# %%
duplicados = merge_datos[merge_datos['ID'].duplicated()]
duplicados
# Out:
#             ID                   ROL       SEXO EDAD  FECHA_FALLECIMIENTO  \
# 30   2016-0041  PASAJERO_ACOMPAÑANTE  MASCULINO   SD  2016-03-30 00:00:00
# 99   2016-0126  PASAJERO_ACOMPAÑANTE  MASCULINO   60                   SD
# 164  2017-0026             CONDUCTOR  MASCULINO   19  2017-02-26 00:00:00
# 174  2017-0035  PASAJERO_ACOMPAÑANTE  MASCULINO   32  2017-03-23 00:00:00
# 175  2017-0035  PASAJERO_ACOMPAÑANTE  MASCULINO   30  2017-03-23 00:00:00
# 177  2017-0036             CONDUCTOR  MASCULINO   20  2017-03-29 00:00:00
# 187  2017-0050  PASAJERO_ACOMPAÑANTE  MASCULINO   16  2017-04-28 00:00:00
# 238  2017-0108  PASAJERO_ACOMPAÑANTE  MASCULINO   10  2017-09-02 00:00:00
# 243  2017-0112  PASAJERO_ACOMPAÑANTE  MASCULINO   SD  2017-09-13 00:00:00
# 254  2017-0126             CONDUCTOR  MASCULINO   36  2017-10-14 00:00:00
# 278  2017-0153             CONDUCTOR  MASCULINO   30  2017-12-12 00:00:00
# 301  2018-0015  PASAJERO_ACOMPAÑANTE  MASCULINO   19  2018-02-06 00:00:00
# 313  2018-0026  PASAJERO_ACOMPAÑANTE  MASCULINO   30  2018-03-09 00:00:00
# 326  2018-0038                PEATON  MASCULINO   61  2018-04-20 00:00:00
# 374  2018-0085             CONDUCTOR  MASCULINO   30  2018-08-03 00:00:00
# 388  2018-0098  PASAJERO_ACOMPAÑANTE  MASCULINO   54  2018-09-09 00:00:00
# 419  2018-0128  PASAJERO_ACOMPAÑANTE   FEMENINO   39  2018-11-25 00:00:00
# 445  2019-0010                PEATON  MASCULINO   59  2019-02-02 00:00:00
# 577  2020-0038             CONDUCTOR  MASCULINO   64  2020-08-30 00:00:00
# 603  2020-0063  PASAJERO_ACOMPAÑANTE  MASCULINO   21  2020-12-05 00:00:00
# 617  2020-0077  PASAJERO_ACOMPAÑANTE   FEMENINO   24  2020-12-25 00:00:00
#
#      N_VICTIMAS      FECHA  AAAA  MM  DD  ...   Altura               Cruce  \
# 30            2 2016-03-29  2016   3  29  ...      NaN  RIVERA INDARTE AV.
# 99            2 2016-09-18  2016   9  18  ...      NaN           TINOGASTA
# 164           2 2017-02-26  2017   2  26  ...      NaN            FOURNIER
# 174           3 2017-03-23  2017   3  23  ...      NaN  VILLAFLOR, AZUCENA
# 175           3 2017-03-23  2017   3  23  ...      NaN  VILLAFLOR, AZUCENA
# 177           2 2017-03-29  2017   3  29  ...      NaN             CAMPANA
# 187           2 2017-04-28  2017   4  28  ...      NaN                 NaN
# 238           2 2017-09-02  2017   9   2  ...      NaN             MACHAIN
# 243           2 2017-09-10  2017   9  10  ...      NaN                 NaN
# 254           2 2017-10-14  2017  10  14  ...      NaN     CA?ADA DE GOMEZ
# 278           2 2017-12-11  2017  12  11  ...      NaN        LA PLATA AV.
# 301           2 2018-02-06  2018   2   6  ...   2800.0                 NaN
# 313           2 2018-03-09  2018   3   9  ...      NaN           SAENZ AV.
# 326           2 2018-04-20  2018   4  20  ...   1571.0                 NaN
# 374           2 2018-08-03  2018   8   3  ...      NaN  GARAY, JUAN DE AV.
# 388           2 2018-09-09  2018   9   9  ...      NaN    BERON DE ASTRADA
# 419           2 2018-11-25  2018  11  25  ...  11200.0                 NaN
# 445           2 2019-02-02  2019   2   2  ...   4100.0                 NaN
# 577           2 2020-08-30  2020   8  30  ...      NaN     DIAZ, CNEL. AV.
# 603           2 2020-12-05  2020  12   5  ...      NaN         ALTA GRACIA
# 617           2 2020-12-25  2020  12  25  ...      NaN        PUNTA ARENAS
#
#                                  Dirección Normalizada COMUNA  \
# 30                 DIRECTORIO AV. y RIVERA INDARTE AV.      7
# 99                                IRIGOYEN y TINOGASTA     10
# 164                      MORENO, PERITO AV. y FOURNIER      4
# 174  ACHAVAL RODRIGUEZ, T., DR. AV. y VILLAFLOR, AZ...      1
# 175  ACHAVAL RODRIGUEZ, T., DR. AV. y VILLAFLOR, AZ...      1
# 177                           PAZ, GRAL. AV. y CAMPANA     12
# 187                                                NaN      9
# 238                           PAZ, GRAL. AV. y MACHAIN     12
# 243                  AUTOPISTA 25 DE MAYO y VARELA AV.      7
# 254                     RIESTRA AV. y CAÃ‘ADA DE GOMEZ      8
# 278                             ROSARIO y LA PLATA AV.      6
# 301                                 AUSTRALIA AV. 2800      4
# 313     RABANAL, FRANCISCO, INTENDENTE AV. y SAENZ AV.      4
# 326                                 RIVADAVIA AV. 1571      1
# 374                ENTRE RIOS AV. y GARAY, JUAN DE AV.      3
# 388                  PAZ, GRAL. AV. y BERON DE ASTRADA      8
# 419                               PAZ, GRAL. AV. 11200      9
# 445                            DEL LIBERTADOR AV. 4100     14
# 577            LAS HERAS GENERAL AV. y DIAZ, CNEL. AV.     14
# 603                           NUEVA YORK y ALTA GRACIA     11
# 617                      SAN MARTIN AV. y PUNTA ARENAS     15
#
#                                    XY (CABA)         pos x         pos y  \
# 30    Point (100232.38564985 99530.25843190)  -58.46076550  -34.63350444
# 99    Point (94275.54271123 100886.87954649)  -58.52572109  -34.62125906
# 164   Point (104113.67806500 97722.68219304)  -58.41842777  -34.64979057
# 174  Point (109583.11620052 102006.72069921)  -58.35881506  -34.61113641
# 175  Point (109583.11620052 102006.72069921)  -58.35881506  -34.61113641
# 177   Point (95300.18060161 105287.23850698)  -58.51452347  -34.58159762
# 187                              Point (. .)             .             .
# 238   Point (97098.48468623 109019.96106626)  -58.49491054  -34.54795581
# 243   Point (100479.14412395 98812.52258620)  -58.45807401  -34.63997430
# 254    Point (98466.20276785 94207.42419155)  -58.48003734  -34.68148508
# 278  Point (103186.65733155 101217.09689755)  -58.42855267  -34.61829385
# 301   Point (107053.47849253 98047.93724144)  -58.38636298  -34.64684275
# 313   Point (104283.01090451 97171.08656182)  -58.41657793  -34.65476216
# 326  Point (106840.31999667 102262.72809661)  -58.38872177  -34.60885045
# 374  Point (106612.54991859 100244.75667446)  -58.39118948  -34.62704273
# 388    Point (99203.46279192 92552.75548716)  -58.47199387  -34.69640164
# 419    Point (94027.41355272 98150.01779732)  -58.52844623  -34.64592873
# 445  Point (103359.87920798 106617.17056502)  -58.42668489  -34.56961468
# 577  Point (105241.05562982 105080.52102657)  -58.40617526  -34.58345898
# 603   Point (94080.62190808 102083.62453795)  -58.52783814  -34.61047001
# 617   Point (99182.71320106 103123.43585183)  -58.47220945  -34.60111373
#
#         PARTICIPANTES      VICTIMA      ACUSADO
# 30        MOTO-CARGAS         MOTO       CARGAS
# 99        AUTO-CARGAS         AUTO       CARGAS
# 164  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 174  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 175  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 177    MOTO-PASAJEROS         MOTO    PASAJEROS
# 187       MOTO-CARGAS         MOTO       CARGAS
# 238  AUTO-OBJETO FIJO  OBJETO FIJO         AUTO
# 243  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 254  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 278    MOTO-PASAJEROS         MOTO    PASAJEROS
# 301    MOTO-PASAJEROS         MOTO    PASAJEROS
# 313      MOVIL-CARGAS        MOVIL       CARGAS
# 326       PEATON-AUTO       PEATON         AUTO
# 374    MOTO-PASAJEROS         MOTO    PASAJEROS
# 388         AUTO-AUTO         AUTO         AUTO
# 419    AUTO-PASAJEROS         AUTO    PASAJEROS
# 445       PEATON-AUTO       PEATON         AUTO
# 577         AUTO-AUTO         AUTO         AUTO
# 603  PEATON_MOTO-MOTO  PEATON_MOTO         MOTO
# 617         MOTO-AUTO         MOTO         AUTO
#
# [21 rows x 25 columns]

# %% [markdown]
# ##### Se verifican que existan la misma cantidad de duplidos en el dataframe

# %%
# Se comprueba uno de los Id a ver que informacion contiene 

duplicado_1 = merge_datos[merge_datos['ID']== '2017-0035']
duplicado_1
# Out:
#             ID                   ROL       SEXO EDAD  FECHA_FALLECIMIENTO  \
# 173  2017-0035             CONDUCTOR  MASCULINO   28  2017-03-23 00:00:00
# 174  2017-0035  PASAJERO_ACOMPAÑANTE  MASCULINO   32  2017-03-23 00:00:00
# 175  2017-0035  PASAJERO_ACOMPAÑANTE  MASCULINO   30  2017-03-23 00:00:00
#
#      N_VICTIMAS      FECHA  AAAA  MM  DD  ... Altura               Cruce  \
# 173           3 2017-03-23  2017   3  23  ...    NaN  VILLAFLOR, AZUCENA
# 174           3 2017-03-23  2017   3  23  ...    NaN  VILLAFLOR, AZUCENA
# 175           3 2017-03-23  2017   3  23  ...    NaN  VILLAFLOR, AZUCENA
#
#                                  Dirección Normalizada COMUNA  \
# 173  ACHAVAL RODRIGUEZ, T., DR. AV. y VILLAFLOR, AZ...      1
# 174  ACHAVAL RODRIGUEZ, T., DR. AV. y VILLAFLOR, AZ...      1
# 175  ACHAVAL RODRIGUEZ, T., DR. AV. y VILLAFLOR, AZ...      1
#
#                                    XY (CABA)         pos x         pos y  \
# 173  Point (109583.11620052 102006.72069921)  -58.35881506  -34.61113641
# 174  Point (109583.11620052 102006.72069921)  -58.35881506  -34.61113641
# 175  Point (109583.11620052 102006.72069921)  -58.35881506  -34.61113641
#
#         PARTICIPANTES  VICTIMA      ACUSADO
# 173  AUTO-OBJETO FIJO     AUTO  OBJETO FIJO
# 174  AUTO-OBJETO FIJO     AUTO  OBJETO FIJO
# 175  AUTO-OBJETO FIJO     AUTO  OBJETO FIJO
#
# [3 rows x 25 columns]

# %%
merge_datos.columns
# Out:
# Index(['ID', 'ROL', 'SEXO', 'EDAD', 'FECHA_FALLECIMIENTO', 'N_VICTIMAS',
#        'FECHA', 'AAAA', 'MM', 'DD', 'HORA', 'HH', 'LUGAR_DEL_HECHO',
#        'TIPO_DE_CALLE', 'Calle', 'Altura', 'Cruce', 'Dirección Normalizada',
#        'COMUNA', 'XY (CABA)', 'pos x', 'pos y', 'PARTICIPANTES', 'VICTIMA',
#        'ACUSADO'],
#       dtype='object')

# %%
# se procede a normalizar los nombre de las columnas en munisculas
merge_datos.columns = merge_datos.columns.str.lower()

# %%
merge_datos.columns
# Out:
# Index(['id', 'rol', 'sexo', 'edad', 'fecha_fallecimiento', 'n_victimas',
#        'fecha', 'aaaa', 'mm', 'dd', 'hora', 'hh', 'lugar_del_hecho',
#        'tipo_de_calle', 'calle', 'altura', 'cruce', 'dirección normalizada',
#        'comuna', 'xy (caba)', 'pos x', 'pos y', 'participantes', 'victima',
#        'acusado'],
#       dtype='object')

# %% [markdown]
# ## Se Crea un CSV con los datos unidos

# %%
merge_datos.to_csv('merge_data.csv', index=False)

# %%
import pandas as pd

# %%
datos = pd.read_csv('merge_data.csv',encoding='utf-8')

# %% [markdown]
# ## Se comienza a hacer un trabajo de Limpieza y transformacion de los datos

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     717 non-null    object
#  1   rol                    717 non-null    object
#  2   sexo                   717 non-null    object
#  3   edad                   717 non-null    object
#  4   fecha_fallecimiento    717 non-null    object
#  5   n_victimas             717 non-null    int64
#  6   fecha                  717 non-null    object
#  7   aaaa                   717 non-null    int64
#  8   mm                     717 non-null    int64
#  9   dd                     717 non-null    int64
#  10  hora                   717 non-null    object
#  11  hh                     717 non-null    object
#  12  lugar_del_hecho        717 non-null    object
#  13  tipo_de_calle          717 non-null    object
#  14  calle                  716 non-null    object
#  15  altura                 133 non-null    float64
#  16  cruce                  540 non-null    object
#  17  dirección normalizada  708 non-null    object
#  18  comuna                 717 non-null    int64
#  19  xy (caba)              717 non-null    object
#  20  pos x                  717 non-null    object
#  21  pos y                  717 non-null    object
#  22  participantes          717 non-null    object
#  23  victima                717 non-null    object
#  24  acusado                717 non-null    object
# dtypes: float64(1), int64(5), object(19)
# memory usage: 140.2+ KB

# %% [markdown]
# ##### Empecemos a eliminar las columnas que no necesitamos

# %%
datos.iloc[:,:11]
# Out:
#             id                   rol       sexo edad  fecha_fallecimiento  \
# 0    2016-0001             CONDUCTOR  MASCULINO   19  2016-01-01 00:00:00
# 1    2016-0002             CONDUCTOR  MASCULINO   70  2016-01-02 00:00:00
# 2    2016-0003             CONDUCTOR  MASCULINO   30  2016-01-03 00:00:00
# 3    2016-0004             CONDUCTOR  MASCULINO   18                   SD
# 4    2016-0005             CONDUCTOR  MASCULINO   29  2016-02-01 00:00:00
# ..         ...                   ...        ...  ...                  ...
# 712  2021-0092                PEATON   FEMENINO   50  2021-12-12 00:00:00
# 713  2021-0093  PASAJERO_ACOMPAÑANTE   FEMENINO   18  2021-12-18 00:00:00
# 714  2021-0094  PASAJERO_ACOMPAÑANTE   FEMENINO   43  2021-12-20 00:00:00
# 715  2021-0095             CONDUCTOR  MASCULINO   27  2022-01-02 00:00:00
# 716  2021-0096             CONDUCTOR  MASCULINO   60  2021-12-20 00:00:00
#
#      n_victimas       fecha  aaaa  mm  dd      hora
# 0             1  2016-01-01  2016   1   1  04:00:00
# 1             1  2016-01-02  2016   1   2  01:15:00
# 2             1  2016-01-03  2016   1   3  07:00:00
# 3             1  2016-01-10  2016   1  10  00:00:00
# 4             1  2016-01-21  2016   1  21  05:20:00
# ..          ...         ...   ...  ..  ..       ...
# 712           1  2021-12-12  2021  12  12  06:20:00
# 713           1  2021-12-13  2021  12  13  17:10:00
# 714           1  2021-12-20  2021  12  20  01:10:00
# 715           1  2021-12-30  2021  12  30  00:43:00
# 716           1  2021-12-15  2021  12  15  10:30:00
#
# [717 rows x 11 columns]

# %%
datos[datos['fecha_fallecimiento']=='SD']
# Out:
#             id                   rol       sexo edad fecha_fallecimiento  \
# 3    2016-0004             CONDUCTOR  MASCULINO   18                  SD
# 16   2016-0022  PASAJERO_ACOMPAÑANTE  MASCULINO   41                  SD
# 19   2016-0027  PASAJERO_ACOMPAÑANTE  MASCULINO   34                  SD
# 22   2016-0031             CONDUCTOR  MASCULINO   21                  SD
# 33   2016-0045             CONDUCTOR  MASCULINO   SD                  SD
# ..         ...                   ...        ...  ...                 ...
# 221  2017-0089                    SD  MASCULINO   23                  SD
# 242  2017-0112  PASAJERO_ACOMPAÑANTE  MASCULINO    1                  SD
# 246  2017-0115             CONDUCTOR  MASCULINO   34                  SD
# 253  2017-0126  PASAJERO_ACOMPAÑANTE  MASCULINO   39                  SD
# 280  2017-0155                    SD  MASCULINO   77                  SD
#
#      n_victimas       fecha  aaaa  mm  dd  ...  altura  \
# 3             1  2016-01-10  2016   1  10  ...     NaN
# 16            1  2016-02-21  2016   2  21  ...     NaN
# 19            1  2016-02-28  2016   2  28  ...     NaN
# 22            1  2016-03-08  2016   3   8  ...     NaN
# 33            1  2016-04-11  2016   4  11  ...     NaN
# ..          ...         ...   ...  ..  ..  ...     ...
# 221           1  2017-07-13  2017   7  13  ...   901.0
# 242           2  2017-09-10  2017   9  10  ...     NaN
# 246           1  2017-09-19  2017   9  19  ...     NaN
# 253           2  2017-10-14  2017  10  14  ...     NaN
# 280           1  2017-12-12  2017  12  12  ...  6350.0
#
#                          cruce                      dirección normalizada  \
# 3     VILLEGAS, CONRADO, GRAL.  LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.
# 16              ALSINA, ADOLFO            9 DE JULIO AV. y ALSINA, ADOLFO
# 19               DIAZ, AVELINO            CURAPALIGUE AV. y DIAZ, AVELINO
# 22             ROCA, CNEL. AV.           PAZ, GRAL. AV. y ROCA, CNEL. AV.
# 33          DEL LIBERTADOR AV.        PAZ, GRAL. AV. y DEL LIBERTADOR AV.
# ..                         ...                                        ...
# 221                        NaN                 LEGUIZAMON, MARTINIANO 901
# 242                        NaN          AUTOPISTA 25 DE MAYO y VARELA AV.
# 246  TREINTA Y TRES ORIENTALES      PAVON AV. y TREINTA Y TRES ORIENTALES
# 253            CA?ADA DE GOMEZ             RIESTRA AV. y CAÃ‘ADA DE GOMEZ
# 280                        NaN                         RIVADAVIA AV. 6350
#
#     comuna                                xy (caba)         pos x  \
# 3        8    Point (99840.65224780 94269.16534422)  -58.46503904
# 16       1  Point (107507.39502374 102046.08333077)  -58.38144696
# 19       7   Point (101679.82794245 98973.02976850)  -58.44497874
# 22       8    Point (99327.01838497 92326.91130631)  -58.47064556
# 33      13   Point (99620.34936816 110483.29286598)  -58.46743471
# ..     ...                                      ...           ...
# 221      9    Point (95246.78684010 97935.32361317)  -58.51514709
# 242      7   Point (100479.14412395 98812.52258620)  -58.45807401
# 246      5   Point (103803.42869640 99818.79654291)  -58.42182126
# 253      8    Point (98466.20276785 94207.42419155)  -58.48003734
# 280      7  Point (100674.98109200 100299.64949548)  -58.45593915
#
#             pos y     participantes  victima      acusado
# 3    -34.68092974           MOTO-SD     MOTO           SD
# 16   -34.61079875         MOTO-AUTO     MOTO         AUTO
# 19   -34.63852623         AUTO-AUTO     AUTO         AUTO
# 22   -34.69843756    MOTO-PASAJEROS     MOTO    PASAJEROS
# 33   -34.53476874           MOTO-SD     MOTO           SD
# ..            ...               ...      ...          ...
# 221  -34.64787051           SD-AUTO       SD         AUTO
# 242  -34.63997430  AUTO-OBJETO FIJO     AUTO  OBJETO FIJO
# 246  -34.63089661    MOTO-BICICLETA     MOTO    BICICLETA
# 253  -34.68148508  AUTO-OBJETO FIJO     AUTO  OBJETO FIJO
# 280  -34.62656868           SD-MOTO       SD         MOTO
#
# [68 rows x 25 columns]

# %%
datos['rol'].value_counts()
# Out:
# CONDUCTOR               330
# PEATON                  267
# PASAJERO_ACOMPAÑANTE     80
# CICLISTA                 29
# SD                       11
# Name: rol, dtype: int64

# %% [markdown]
# Como existen datos faltantes en la columna de rol procedemos a imputar dichas celdas por la moda

# %%
moda= datos['rol'].mode()[0]
moda
# Out:
# 'CONDUCTOR'

# %%
datos['rol'] = datos['rol'].replace('SD',moda)

# %%
datos['rol'].value_counts()
# Out:
# CONDUCTOR               341
# PEATON                  267
# PASAJERO_ACOMPAÑANTE     80
# CICLISTA                 29
# Name: rol, dtype: int64

# %% [markdown]
# Como existen datos faltantes en la columna de sexo procedemos a imputar dichas celdas por la moda

# %%
datos['sexo'].value_counts()
# Out:
# MASCULINO    545
# FEMENINO     166
# SD             6
# Name: sexo, dtype: int64

# %%
moda= datos['sexo'].mode()[0]
moda
# Out:
# 'MASCULINO'

# %%
datos['sexo'] = datos['sexo'].replace('SD',moda)

# %%
datos['sexo'].value_counts()
# Out:
# MASCULINO    551
# FEMENINO     166
# Name: sexo, dtype: int64

# %%
datos['edad'].value_counts()
# Out:
# SD    53
# 30    28
# 29    24
# 23    24
# 27    20
#       ..
# 11     1
# 13     1
# 85     1
# 7      1
# 88     1
# Name: edad, Length: 86, dtype: int64

# %% [markdown]
# Como podemos ver existen 53 datos faltantes, analizaremos la columna a ver por cual valor se puede imputar

# %%
import numpy as np

datos['edad'] = datos['edad'].str.replace('SD', str(np.nan))

# %%
# Convierte la columna 'edad' en números, reemplazando 'NaN' con valores NaN
datos['edad'] = pd.to_numeric(datos['edad'], errors='coerce')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Supongamos que tienes un DataFrame llamado 'datos' con una columna 'edad'

# Grafica un histograma de la columna 'edad'
plt.hist(datos['edad'], bins=40, color='skyblue', edgecolor='black')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Histograma de Edades')

# Calcula la media y la mediana de la columna 'edad'
media_edad = datos['edad'].mean()
mediana_edad = datos['edad'].median()

# Agrega líneas verticales para mostrar la media y la mediana
plt.axvline(media_edad, color='red', linestyle='dashed', linewidth=2, label=f'Media: {media_edad:.2f}')
plt.axvline(mediana_edad, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_edad}')

# Muestra una leyenda con las etiquetas de la media y la mediana
plt.legend()

plt.show()

# %% [markdown]
# Como los datos no se ven tan simetricos, preferiremos imputar los valores faltantes por la mediana al parecer hay datos muy alejados de la media (outliers)

# %%
media = datos['edad'].mean().round(2)
media
# Out:
# 42.17

# %%
mediana = datos['edad'].median().round(2)
mediana
# Out:
# 37.0

# %%
# Reemplaza los valores NaN por la mediana en la columna 'edad'
datos['edad'].fillna(mediana, inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Supongamos que tienes un DataFrame llamado 'datos' con una columna 'edad'

# Grafica un histograma de la columna 'edad'
plt.hist(datos['edad'], bins=40, color='skyblue', edgecolor='black')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Histograma de Edades')

# Calcula la media y la mediana de la columna 'edad'
media_edad = datos['edad'].mean()
mediana_edad = datos['edad'].median()

# Agrega líneas verticales para mostrar la media y la mediana
plt.axvline(media_edad, color='red', linestyle='dashed', linewidth=2, label=f'Media: {media_edad:.2f}')
plt.axvline(mediana_edad, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_edad}')

# Muestra una leyenda con las etiquetas de la media y la mediana
plt.legend()

plt.show()

# %% [markdown]
# Procedemos con la columna que continua 'fecha_fallecimiento'

# %%
datos['fecha_fallecimiento']
# Out:
# 0      2016-01-01 00:00:00
# 1      2016-01-02 00:00:00
# 2      2016-01-03 00:00:00
# 3                       SD
# 4      2016-02-01 00:00:00
#               ...
# 712    2021-12-12 00:00:00
# 713    2021-12-18 00:00:00
# 714    2021-12-20 00:00:00
# 715    2022-01-02 00:00:00
# 716    2021-12-20 00:00:00
# Name: fecha_fallecimiento, Length: 717, dtype: object

# %%
datos[datos['fecha_fallecimiento']=='SD']
# Out:
#             id                   rol       sexo  edad fecha_fallecimiento  \
# 3    2016-0004             CONDUCTOR  MASCULINO  18.0                  SD
# 16   2016-0022  PASAJERO_ACOMPAÑANTE  MASCULINO  41.0                  SD
# 19   2016-0027  PASAJERO_ACOMPAÑANTE  MASCULINO  34.0                  SD
# 22   2016-0031             CONDUCTOR  MASCULINO  21.0                  SD
# 33   2016-0045             CONDUCTOR  MASCULINO  37.0                  SD
# ..         ...                   ...        ...   ...                 ...
# 221  2017-0089             CONDUCTOR  MASCULINO  23.0                  SD
# 242  2017-0112  PASAJERO_ACOMPAÑANTE  MASCULINO   1.0                  SD
# 246  2017-0115             CONDUCTOR  MASCULINO  34.0                  SD
# 253  2017-0126  PASAJERO_ACOMPAÑANTE  MASCULINO  39.0                  SD
# 280  2017-0155             CONDUCTOR  MASCULINO  77.0                  SD
#
#      n_victimas       fecha  aaaa  mm  dd  ...  altura  \
# 3             1  2016-01-10  2016   1  10  ...     NaN
# 16            1  2016-02-21  2016   2  21  ...     NaN
# 19            1  2016-02-28  2016   2  28  ...     NaN
# 22            1  2016-03-08  2016   3   8  ...     NaN
# 33            1  2016-04-11  2016   4  11  ...     NaN
# ..          ...         ...   ...  ..  ..  ...     ...
# 221           1  2017-07-13  2017   7  13  ...   901.0
# 242           2  2017-09-10  2017   9  10  ...     NaN
# 246           1  2017-09-19  2017   9  19  ...     NaN
# 253           2  2017-10-14  2017  10  14  ...     NaN
# 280           1  2017-12-12  2017  12  12  ...  6350.0
#
#                          cruce                      dirección normalizada  \
# 3     VILLEGAS, CONRADO, GRAL.  LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.
# 16              ALSINA, ADOLFO            9 DE JULIO AV. y ALSINA, ADOLFO
# 19               DIAZ, AVELINO            CURAPALIGUE AV. y DIAZ, AVELINO
# 22             ROCA, CNEL. AV.           PAZ, GRAL. AV. y ROCA, CNEL. AV.
# 33          DEL LIBERTADOR AV.        PAZ, GRAL. AV. y DEL LIBERTADOR AV.
# ..                         ...                                        ...
# 221                        NaN                 LEGUIZAMON, MARTINIANO 901
# 242                        NaN          AUTOPISTA 25 DE MAYO y VARELA AV.
# 246  TREINTA Y TRES ORIENTALES      PAVON AV. y TREINTA Y TRES ORIENTALES
# 253            CA?ADA DE GOMEZ             RIESTRA AV. y CAÃ‘ADA DE GOMEZ
# 280                        NaN                         RIVADAVIA AV. 6350
#
#     comuna                                xy (caba)         pos x  \
# 3        8    Point (99840.65224780 94269.16534422)  -58.46503904
# 16       1  Point (107507.39502374 102046.08333077)  -58.38144696
# 19       7   Point (101679.82794245 98973.02976850)  -58.44497874
# 22       8    Point (99327.01838497 92326.91130631)  -58.47064556
# 33      13   Point (99620.34936816 110483.29286598)  -58.46743471
# ..     ...                                      ...           ...
# 221      9    Point (95246.78684010 97935.32361317)  -58.51514709
# 242      7   Point (100479.14412395 98812.52258620)  -58.45807401
# 246      5   Point (103803.42869640 99818.79654291)  -58.42182126
# 253      8    Point (98466.20276785 94207.42419155)  -58.48003734
# 280      7  Point (100674.98109200 100299.64949548)  -58.45593915
#
#             pos y     participantes  victima      acusado
# 3    -34.68092974           MOTO-SD     MOTO           SD
# 16   -34.61079875         MOTO-AUTO     MOTO         AUTO
# 19   -34.63852623         AUTO-AUTO     AUTO         AUTO
# 22   -34.69843756    MOTO-PASAJEROS     MOTO    PASAJEROS
# 33   -34.53476874           MOTO-SD     MOTO           SD
# ..            ...               ...      ...          ...
# 221  -34.64787051           SD-AUTO       SD         AUTO
# 242  -34.63997430  AUTO-OBJETO FIJO     AUTO  OBJETO FIJO
# 246  -34.63089661    MOTO-BICICLETA     MOTO    BICICLETA
# 253  -34.68148508  AUTO-OBJETO FIJO     AUTO  OBJETO FIJO
# 280  -34.62656868           SD-MOTO       SD         MOTO
#
# [68 rows x 25 columns]

# %% [markdown]
# Procedemos a imputar la fecha de fallecimiento con la fecha del Hecho

# %%
# Reemplaza "SD" en 'fecha_fallecimiento' con los valores de 'fecha'
datos.loc[datos['fecha_fallecimiento'] == 'SD', 'fecha_fallecimiento'] = datos['fecha']

# %%
datos[datos['id']=='2016-0027']
# Out:
#            id                   rol       sexo  edad fecha_fallecimiento  \
# 19  2016-0027  PASAJERO_ACOMPAÑANTE  MASCULINO  34.0          2016-02-28
#
#     n_victimas       fecha  aaaa  mm  dd  ... altura          cruce  \
# 19           1  2016-02-28  2016   2  28  ...    NaN  DIAZ, AVELINO
#
#               dirección normalizada comuna  \
# 19  CURAPALIGUE AV. y DIAZ, AVELINO      7
#
#                                  xy (caba)         pos x         pos y  \
# 19  Point (101679.82794245 98973.02976850)  -58.44497874  -34.63852623
#
#    participantes  victima acusado
# 19     AUTO-AUTO     AUTO    AUTO
#
# [1 rows x 25 columns]

# %% [markdown]
# Cambiamos el formato de la columna

# %%
datos['fecha_fallecimiento'] = pd.to_datetime(datos['fecha_fallecimiento'])

# %% [markdown]
# Revisamos la columna numero de victima

# %%
datos['n_victimas'].value_counts()
# Out:
# 1    676
# 2     38
# 3      3
# Name: n_victimas, dtype: int64

# %% [markdown]
# Se puede apreciar que no existen valores fuera de lo normal, por lo que no se realiza ninguna transformacion

# %% [markdown]
# Se contina con la columna de Fecha

# %%
datos['fecha'].isna().sum()
# Out:
# 0

# %%
datos[datos['fecha']=='SD']

# %%
datos = datos.rename(columns={'fecha':'fecha_hecho'})

# %% [markdown]
# Se contina con la columna de hora

# %%
datos['hora']
# Out:
# 0      04:00:00
# 1      01:15:00
# 2      07:00:00
# 3      00:00:00
# 4      05:20:00
#          ...
# 712    06:20:00
# 713    17:10:00
# 714    01:10:00
# 715    00:43:00
# 716    10:30:00
# Name: hora, Length: 717, dtype: object

# %%
datos[datos['hora']=='SD']
# Out:
#             id        rol       sexo  edad  fecha_fallecimiento  n_victimas  \
# 537  2019-0103  CONDUCTOR  MASCULINO  24.0  2019-12-18 00:00:00           1
#
#     fecha_hecho  aaaa  mm  dd  ... altura   cruce    dirección normalizada  \
# 537  2019-12-18  2019  12  18  ...    NaN  GRIVEO  PAZ, GRAL. AV. y GRIVEO
#
#     comuna                               xy (caba)         pos x  \
# 537     11  Point (94643.11254058 103831.57115061)  -58.52169422
#
#             pos y participantes  victima acusado
# 537  -34.59471640     MOTO-MOTO     MOTO    MOTO
#
# [1 rows x 25 columns]

# %% [markdown]
# Com existe un index con la hora en SD la imputamos por la hora 00:00:00

# %%
datos['hora'] = datos['hora'].replace('SD','00:00:00')

# %%
datos.iloc[:,12:19]
# Out:
#                                lugar_del_hecho tipo_de_calle  \
# 0    AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA
# 1            AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ
# 2                           AV ENTRE RIOS 2034       AVENIDA
# 3        AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA
# 4    AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA
# ..                                         ...           ...
# 712             AV. RIVADAVIA Y AV. PUEYRREDON       AVENIDA
# 713                          AV. RIESTRA Y MOM       AVENIDA
# 714                    AU DELLEPIANE Y LACARRA     AUTOPISTA
# 715                        AV. GAONA Y TERRADA       AVENIDA
# 716                         AV. EVA PERON 4071       AVENIDA
#
#                             calle  altura  \
# 0                PIEDRA BUENA AV.     NaN
# 1                  PAZ, GRAL. AV.     NaN
# 2                  ENTRE RIOS AV.  2034.0
# 3                  LARRAZABAL AV.     NaN
# 4                    SAN JUAN AV.     NaN
# ..                            ...     ...
# 712                 RIVADAVIA AV.     NaN
# 713                   RIESTRA AV.     NaN
# 714  DELLEPIANE, LUIS, TTE. GRAL.     NaN
# 715                     GAONA AV.     NaN
# 716                PERON, EVA AV.  4071.0
#
#                                    cruce  \
# 0    FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                    DE LOS CORRALES AV.
# 2                                    NaN
# 3               VILLEGAS, CONRADO, GRAL.
# 4                SAENZ PE?A, LUIS, PRES.
# ..                                   ...
# 712                       PUEYRREDON AV.
# 713                                  MOM
# 714                          LACARRA AV.
# 715                              TERRADA
# 716                                  NaN
#
#                                  dirección normalizada  comuna
# 0    PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...       8
# 1                 PAZ, GRAL. AV. y DE LOS CORRALES AV.       9
# 2                                  ENTRE RIOS AV. 2034       1
# 3            LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.       8
# 4              SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.       1
# ..                                                 ...     ...
# 712                     RIVADAVIA AV. y PUEYRREDON AV.       3
# 713                                  RIESTRA AV. y MOM       7
# 714         DELLEPIANE, LUIS, TTE. GRAL. y LACARRA AV.       9
# 715                                GAONA AV. y TERRADA      11
# 716                                PERON, EVA AV. 4071       9
#
# [717 rows x 7 columns]

# %%
datos[datos['lugar_del_hecho']=='SD']
# Out:
#             id     rol       sexo  edad fecha_fallecimiento  n_victimas  \
# 121  2016-0151  PEATON  MASCULINO  37.0          2016-11-18           1
#
#     fecha_hecho  aaaa  mm  dd  ... altura cruce dirección normalizada comuna  \
# 121  2016-11-18  2016  11  18  ...    NaN   NaN                   NaN      0
#
#        xy (caba)  pos x pos y participantes  victima acusado
# 121  Point (. .)      .     .     PEATON-SD   PEATON      SD
#
# [1 rows x 25 columns]

# %%
datos['tipo_de_calle'].value_counts()
# Out:
# AVENIDA      442
# CALLE        138
# GRAL PAZ      69
# AUTOPISTA     68
# Name: tipo_de_calle, dtype: int64

# %% [markdown]
# Revisando el comportamiento de las direcciones que faltan no podemos eliminar las filas ya que contienen informacionque nos puede ser de utilidad para el EDA

# %%
datos[datos['lugar_del_hecho']=='SD']
# Out:
#             id     rol       sexo  edad fecha_fallecimiento  n_victimas  \
# 121  2016-0151  PEATON  MASCULINO  37.0          2016-11-18           1
#
#     fecha_hecho  aaaa  mm  dd  ... altura cruce dirección normalizada comuna  \
# 121  2016-11-18  2016  11  18  ...    NaN   NaN                   NaN      0
#
#        xy (caba)  pos x pos y participantes  victima acusado
# 121  Point (. .)      .     .     PEATON-SD   PEATON      SD
#
# [1 rows x 25 columns]

# %%
datos[datos['xy (caba)']=='Point (. .)']
# Out:
#             id                   rol       sexo  edad  fecha_fallecimiento  \
# 36   2016-0049             CONDUCTOR  MASCULINO  37.0           2016-04-17
# 39   2016-0052             CONDUCTOR  MASCULINO  37.0           2016-04-20
# 72   2016-0096             CONDUCTOR  MASCULINO  37.0           2016-07-25
# 108  2016-0136             CONDUCTOR  MASCULINO  37.0           2016-10-25
# 121  2016-0151                PEATON  MASCULINO  37.0           2016-11-18
# 141  2016-0174             CONDUCTOR  MASCULINO  37.0           2016-12-27
# 182  2017-0042             CONDUCTOR  MASCULINO  37.0  2017-04-10 00:00:00
# 186  2017-0050             CONDUCTOR  MASCULINO  46.0  2017-04-28 00:00:00
# 187  2017-0050  PASAJERO_ACOMPAÑANTE  MASCULINO  16.0  2017-04-28 00:00:00
# 188  2017-0051             CONDUCTOR  MASCULINO  33.0  2017-05-01 00:00:00
# 266  2017-0140             CONDUCTOR  MASCULINO  24.0  2017-11-19 00:00:00
# 327  2018-0039                PEATON  MASCULINO  37.0  2018-04-21 00:00:00
# 564  2020-0026             CONDUCTOR  MASCULINO  28.0  2020-05-17 00:00:00
# 578  2020-0039                PEATON  MASCULINO  44.0  2020-09-01 00:00:00
# 642  2021-0023             CONDUCTOR  MASCULINO  24.0  2021-03-01 00:00:00
#
#      n_victimas fecha_hecho  aaaa  mm  dd  ... altura cruce  \
# 36            1  2016-04-17  2016   4  17  ...    NaN   NaN
# 39            1  2016-04-20  2016   4  20  ...    NaN   NaN
# 72            1  2016-07-25  2016   7  25  ...    NaN   NaN
# 108           1  2016-10-25  2016  10  25  ...    NaN   NaN
# 121           1  2016-11-18  2016  11  18  ...    NaN   NaN
# 141           1  2016-12-27  2016  12  27  ...    NaN   NaN
# 182           1  2017-04-10  2017   4  10  ...    NaN   NaN
# 186           2  2017-04-28  2017   4  28  ...    NaN   NaN
# 187           2  2017-04-28  2017   4  28  ...    NaN   NaN
# 188           1  2017-05-01  2017   5   1  ...    NaN   NaN
# 266           1  2017-11-19  2017  11  19  ...    NaN   NaN
# 327           1  2018-04-21  2018   4  21  ...    NaN   NaN
# 564           1  2020-05-17  2020   5  17  ...    NaN   NaN
# 578           1  2020-09-01  2020   9   1  ...    NaN   NaN
# 642           1  2021-03-01  2021   3   1  ...    NaN   NaN
#
#                           dirección normalizada comuna    xy (caba)  \
# 36   AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI      4  Point (. .)
# 39                                          NaN     13  Point (. .)
# 72         AUTOPISTA DELLEPIANE LUIS TTE. GRAL.      8  Point (. .)
# 108                                         NaN      4  Point (. .)
# 121                                         NaN      0  Point (. .)
# 141                        AUTOPISTA 25 DE MAYO      0  Point (. .)
# 182                       LUGONES, LEOPOLDO AV.     14  Point (. .)
# 186                                         NaN      9  Point (. .)
# 187                                         NaN      9  Point (. .)
# 188                                         NaN      7  Point (. .)
# 266  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI      4  Point (. .)
# 327                                         NaN     14  Point (. .)
# 564                                         NaN     14  Point (. .)
# 578                                  MURGUIONDO      9  Point (. .)
# 642                                         NaN      4  Point (. .)
#
#                   pos x               pos y     participantes  victima  \
# 36   -58.37714647568196  -34.63657525428238             SD-SD       SD
# 39                    .                   .           MOTO-SD     MOTO
# 72   -58.47433193007387  -34.66684950051973       MOTO-CARGAS     MOTO
# 108                   .                   .       MOTO-CARGAS     MOTO
# 121                   .                   .         PEATON-SD   PEATON
# 141                   .                   .             SD-SD       SD
# 182                   .                   .       MOTO-CARGAS     MOTO
# 186                   .                   .       MOTO-CARGAS     MOTO
# 187                   .                   .       MOTO-CARGAS     MOTO
# 188                   .                   .         AUTO-AUTO     AUTO
# 266                   .                   .    MOTO-PASAJEROS     MOTO
# 327                   .                   .       PEATON-AUTO   PEATON
# 564                   .                   .  MOTO-OBJETO FIJO     MOTO
# 578                   .                   .     PEATON-CARGAS   PEATON
# 642                   .                   .       MOTO-CARGAS     MOTO
#
#          acusado
# 36            SD
# 39            SD
# 72        CARGAS
# 108       CARGAS
# 121           SD
# 141           SD
# 182       CARGAS
# 186       CARGAS
# 187       CARGAS
# 188         AUTO
# 266    PASAJEROS
# 327         AUTO
# 564  OBJETO FIJO
# 578       CARGAS
# 642       CARGAS
#
# [15 rows x 25 columns]

# %%
datos['participantes'].value_counts()
# Out:
# PEATON-PASAJEROS       105
# MOTO-AUTO               84
# MOTO-CARGAS             80
# PEATON-AUTO             79
# MOTO-PASAJEROS          50
# MOTO-OBJETO FIJO        40
# PEATON-CARGAS           38
# AUTO-AUTO               33
# PEATON-MOTO             30
# AUTO-OBJETO FIJO        28
# MOTO-MOTO               25
# MULTIPLE                17
# AUTO-CARGAS             15
# AUTO-PASAJEROS          10
# BICICLETA-CARGAS        10
# MOTO-SD                  9
# BICICLETA-PASAJEROS      8
# BICICLETA-AUTO           8
# SD-SD                    5
# PEATON-BICICLETA         5
# CARGAS-CARGAS            4
# PEATON-SD                4
# AUTO-SD                  4
# PASAJEROS-PASAJEROS      3
# SD-AUTO                  2
# MOVIL-CARGAS             2
# MOTO-BICICLETA           2
# MOTO-OTRO                2
# PEATON_MOTO-MOTO         2
# MOTO-MOVIL               2
# BICICLETA-OTRO           1
# AUTO-MOVIL               1
# BICICLETA-TREN           1
# CARGAS-PASAJEROS         1
# CARGAS-AUTO              1
# PASAJEROS-AUTO           1
# SD-MOTO                  1
# CARGAS-OBJETO FIJO       1
# MOVIL-PASAJEROS          1
# SD-CARGAS                1
# PASAJEROS-SD             1
# Name: participantes, dtype: int64

# %%
datos['victima'].value_counts()
# Out:
# MOTO           302
# PEATON         266
# AUTO            92
# BICICLETA       29
# SD               9
# CARGAS           7
# PASAJEROS        5
# MOVIL            3
# OBJETO FIJO      2
# PEATON_MOTO      2
# Name: victima, dtype: int64

# %%
moda = datos['victima'].mode()[0]
moda
# Out:
# 'MOTO'

# %%
datos['victima'] = datos['victima'].replace('SD',moda)

# %%
datos['acusado'].value_counts()
# Out:
# AUTO           210
# PASAJEROS      178
# CARGAS         150
# OBJETO FIJO     67
# MOTO            58
# SD              23
# MULTIPLE        17
# BICICLETA        7
# OTRO             6
# TREN             1
# Name: acusado, dtype: int64

# %%
moda = datos['acusado'].mode()[0]
moda
# Out:
# 'AUTO'

# %%
datos['acusado'] = datos['acusado'].replace('SD',moda)

# %%
datos['acusado'].value_counts()
# Out:
# AUTO           233
# PASAJEROS      178
# CARGAS         150
# OBJETO FIJO     67
# MOTO            58
# MULTIPLE        17
# BICICLETA        7
# OTRO             6
# TREN             1
# Name: acusado, dtype: int64

# %% [markdown]
# Ahora que hemos logrado quitar la mayoria de celdas de SD de acusado y victima, procedemos a reescribir la columna de participantes

# %%
# Crear la columna 'participantes' 
datos['participantes'] = datos['victima'] + '-' + datos['acusado']

# %%
datos['participantes'].value_counts()
# Out:
# PEATON-PASAJEROS       105
# MOTO-AUTO              100
# PEATON-AUTO             83
# MOTO-CARGAS             81
# MOTO-PASAJEROS          50
# MOTO-OBJETO FIJO        40
# PEATON-CARGAS           38
# AUTO-AUTO               37
# PEATON-MOTO             30
# MOTO-MOTO               26
# AUTO-OBJETO FIJO        26
# AUTO-CARGAS             15
# BICICLETA-CARGAS        10
# AUTO-PASAJEROS          10
# MOTO-MULTIPLE            8
# BICICLETA-PASAJEROS      8
# BICICLETA-AUTO           8
# PEATON-MULTIPLE          5
# PEATON-BICICLETA         5
# MOTO-OTRO                4
# CARGAS-CARGAS            4
# AUTO-MULTIPLE            3
# PASAJEROS-PASAJEROS      3
# OBJETO FIJO-AUTO         2
# MOTO-BICICLETA           2
# MOVIL-CARGAS             2
# PASAJEROS-AUTO           2
# PEATON_MOTO-MOTO         2
# CARGAS-OBJETO FIJO       1
# CARGAS-AUTO              1
# MOVIL-PASAJEROS          1
# AUTO-OTRO                1
# CARGAS-PASAJEROS         1
# BICICLETA-MULTIPLE       1
# BICICLETA-TREN           1
# BICICLETA-OTRO           1
# Name: participantes, dtype: int64

# %%
datos['comuna'].value_counts()
# Out:
# 1     93
# 4     79
# 9     75
# 8     67
# 7     62
# 3     46
# 15    45
# 13    40
# 12    39
# 14    37
# 11    33
# 10    30
# 2     25
# 6     22
# 5     22
# 0      2
# Name: comuna, dtype: int64

# %% [markdown]
# Se eliminan las columnas que no se necesitan

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     717 non-null    object
#  1   rol                    717 non-null    object
#  2   sexo                   717 non-null    object
#  3   edad                   717 non-null    float64
#  4   fecha_fallecimiento    717 non-null    object
#  5   n_victimas             717 non-null    int64
#  6   fecha_hecho            717 non-null    object
#  7   aaaa                   717 non-null    int64
#  8   mm                     717 non-null    int64
#  9   dd                     717 non-null    int64
#  10  hora                   717 non-null    object
#  11  hh                     717 non-null    object
#  12  lugar_del_hecho        717 non-null    object
#  13  tipo_de_calle          717 non-null    object
#  14  calle                  716 non-null    object
#  15  altura                 133 non-null    float64
#  16  cruce                  540 non-null    object
#  17  dirección normalizada  708 non-null    object
#  18  comuna                 717 non-null    int64
#  19  xy (caba)              717 non-null    object
#  20  pos x                  717 non-null    object
#  21  pos y                  717 non-null    object
#  22  participantes          717 non-null    object
#  23  victima                717 non-null    object
#  24  acusado                717 non-null    object
# dtypes: float64(2), int64(5), object(18)
# memory usage: 140.2+ KB

# %%
datos.drop(['altura', 'cruce','dirección normalizada'], axis=1, inplace=True)

# %%
datos[datos['calle'].isna()]
# Out:
#             id     rol       sexo  edad fecha_fallecimiento  n_victimas  \
# 121  2016-0151  PEATON  MASCULINO  37.0          2016-11-18           1
#
#     fecha_hecho  aaaa  mm  dd  ... lugar_del_hecho tipo_de_calle calle comuna  \
# 121  2016-11-18  2016  11  18  ...              SD         CALLE   NaN      0
#
#        xy (caba)  pos x pos y participantes victima acusado
# 121  Point (. .)      .     .   PEATON-AUTO  PEATON    AUTO
#
# [1 rows x 22 columns]

# %%
datos.to_csv('hechos_limp.csv',index=False)
